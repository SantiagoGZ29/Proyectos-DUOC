# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoGZ29/Proyectos-DUOC/blob/main/Condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CONDICIONALES: if ,else y elif**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
edad = int(input("Ingrese la una edad: "));
if edad >= 18:
  print(f"Es mayor de edad, tiene {edad} años")
elif edad <0:
  print("Error, no corresponde a una edad")
else:
  print(f"Es menor de edad, tiene {edad} años")
# Out:
# Ingrese la una edad: -5
# Error, no corresponde a una edad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Ingrese sus credenciales")

user1 = input("Ingrese el usuario: ")
pass1 = int(input("Ingrese el su clave: "))

if (user1 == "pedro" and pass1 == 1234):
  print("Bienvenido al sistema")
elif (user1 == "pedro" and pass1 != 1234):
  print("clave incorrecta, vuelva a intentar")
elif (user1 != "pedro" and pass1 == 1234):
  print("usuario incorrecto, vuelva a intentar")
else:
  print("ambos datos incorrectos, vuelva a intentarlo")

print("Ingrese sus credenciales")

user2 = input("Ingrese el usuario: ")
pass2 = input("Ingrese el su clave: ")

if (user2 == "angel" and pass1 == "a4s1"):
  print("Bienvenido al sistema")
elif (user2 == "angel" and pass2 != "a4s1"):
  print("clave incorrecta, vuelva a intentar")
elif (user2 != "angel" and pass2 == "a4s1"):
  print("usuario incorrecto, vuelva a intentar")
else:
  print("ambos datos incorrectos, vuelva a intentarlo")
# Out:
# Ingrese sus credenciales
# Ingrese el usuario: pedro
# Ingrese el su clave: 1234
# Bienvenido al sistema
# Ingrese sus credenciales
# Ingrese el usuario: angel
# Ingrese el su clave: 1234
# clave incorrecta, vuelva a intentar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
perro = "perro"
cocodrilo = "cocodrilo"
conejo = "conejo"
tiburon = "tiburon"
puntaje = 0
pregunta = input("Cúal de los siguientes animales vive en el agua: \n perro \n cocodrilo \n conejo \n tiburon \n")
if pregunta == "cocodrilo":
 puntaje = puntaje + 0.5
elif pregunta == "tiburon":
  puntaje = puntaje + 1
else:
  print(f"El {pregunta}, no es un animal de agua")
print(f"El puntaje obtenido es de {puntaje}")
# Out:
# Cúal de los siguientes animales vive en el agua:
#  perro
#  cocodrilo
#  conejo
#  tiburon
# gato
# El gato, no es un animal de agua
# El puntaje obtenido es de 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Puntaje = 0
print("Bienvenido a nuestro concurso, para participar conteste a las siguientes preguntas: ")
print("1. ¿Qué parte del cuerpo trabaja una sentadilla? \na. Espalda \nb. pecho\nc. piernas\nd. gluteo")
respuesta1 = input()
if respuesta1 == "c":
  print("Respuesta correcta")
  puntaje = puntaje + 2
elif respuesta1 == "d":
  print("Respuesta correcta")
  puntaje = puntaje + 1
else:
  print("Respuesta incorrecta era c o d")

print("Siguiente pregunta: ")
print("2. ¿Cúal película ganó un Oscar? \na. Titanic \nb. Avatar\nc. El club de la pelea\nd. Los minioms 1")
respuesta2 = input()
if respuesta2 == "a":
  print("Respuesta correcta")
  puntaje = puntaje + 1
elif respuesta2 == "b":

  print("Respuesta correcta")
  puntaje = puntaje + 1
else:
  print("Respuesta incorrecta, era a o b")

print("Siguiente pregunta: ")
print("3. ¿Cuantos huesos tiene el cuerpo humano? \na. 100 \nb. 500\nc. 366\nd. 206")
respuesta3 = input()
if respuesta3 == "d":
  print("Respuesta correcta")
  puntaje = puntaje + 3
else:
  print("Respuesta incorrecta, era la d")

print (f"Gracias por participar obtuviste un total de {puntaje} puntos")
# Out:
# Bienvenido a nuestro concurso, para participar conteste a las siguientes preguntas:
# 1. ¿Qué parte del cuerpo trabaja una sentadilla?
# a. Espalda
# b. pecho
# c. piernas
# d. gluteo
# a
# Respuesta incorrecta era c o d
# Siguiente pregunta:
# 2. ¿Cúal película ganó un Oscar?
# a. Titanic
# b. Avatar
# c. El club de la pelea
# d. Los minioms 1
# d
# Respuesta incorrecta, era a o b
# Siguiente pregunta:
# 3. ¿Cuantos huesos tiene el cuerpo humano?
# a. 100
# b. 500
# c. 366
# d. 206
# a
# Respuesta incorrecta, era la d
# Gracias por participar obtuviste un total de 10 puntos

# %% [markdown]
# Algo está fallando, lo volveré a hacer

# %%
puntaje = 0
print("Bienvenido a nuestro concurso, para participar conteste a las siguientes preguntas: ")
print("1. ¿Qué parte del cuerpo trabaja una sentadilla? \na. Espalda \nb. Pecho\nc. Piernas\nd. Hombro")
respuesta1 = input()
if respuesta1 == "c":
  print("Respuesta correcta")
  puntaje = puntaje + 2
  print(f"Su puntaje es de {puntaje}")
else:
  print("Respuesta incorrecta era c")
  print(f"Su puntaje es de {puntaje}")
print("Siguiente pregunta: ")
print("2. ¿Cúal película ganó un Oscar? \na. Titanic \nb. Fury\nc. El club de la pelea\nd. Los minioms 1")
respuesta2 = input()
if respuesta2 == "a":
  print("Respuesta correcta")
  puntaje = puntaje + 2
  print(f"Su puntaje actual es de {puntaje}")
else:
  print("Respuesta incorrecta, era a")

print("Siguiente pregunta: ")
print("3. ¿Cuantos huesos tiene el cuerpo humano? \na. 100 \nb. 500\nc. 366\nd. 206")
respuesta3 = input()
if respuesta3 == "d":
  print("Respuesta correcta")
  puntaje = puntaje + 2
else:
  print("Respuesta incorrecta, era la d")

if respuesta1 == "c" and respuesta2 == "a" and respuesta3 == "d":
  puntaje = puntaje + 1
  print("Tiene un bonus de 1 punto por tener todas correctas")

print (f"Gracias por participar obtuviste un total de {puntaje} puntos")
# Out:
# Bienvenido a nuestro concurso, para participar conteste a las siguientes preguntas:
# 1. ¿Qué parte del cuerpo trabaja una sentadilla?
# a. Espalda
# b. Pecho
# c. Piernas
# d. Hombro
# c
# Respuesta correcta
# Su puntaje es de 2
# Siguiente pregunta:
# 2. ¿Cúal película ganó un Oscar?
# a. Titanic
# b. Fury
# c. El club de la pelea
# d. Los minioms 1
# a
# Respuesta correcta
# Su puntaje actual es de 4
# Siguiente pregunta:
# 3. ¿Cuantos huesos tiene el cuerpo humano?
# a. 100
# b. 500
# c. 366
# d. 206
# d
# Respuesta correcta
# Tiene un bonus de 1 punto por tener todas correctas
# Gracias por participar obtuviste un total de 7 puntos
